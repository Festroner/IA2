# %% [markdown]
# ## Librarias necesarias

# %%
import random
import string
import numpy as np
from math import e
from statistics import mode, mean
from py_linq import Enumerable
import time
import pylab as pl

# %% [markdown]
# ## Declaración de variables globales

# %%
numCiudades=12
numPoblacion=50
generaciones=20000
Q=[0.5, 0.75, 0.95] #Probabilidad de no mutación


#Nombre de todas las ciudades que debe visitar el viajero
ciudades=["Campeche", "Cancun", "chetumal", "chichenitza", 'izamal','playa del carmen','puerto morales','merida','tizimni','TUlum','uxmal',"Valladolid"]

#Genes posibles
asci=string.ascii_uppercase


#Distancias
dis=[
    ['A', [0, 515, 425, 315, 265, 583, 551, 196, 409, 470, 171, 355]],#Campeche
    ['B',[512, 0, 382, 205, 266, 68, 36, 320, 212, 131, 399, 160]], # cancunn
    ['C',[425, 382, 0, 410, 471, 314, 346, 525, 417, 251, 605, 365]],# chetumal, 
    ['D',[315, 205, 410, 0, 62, 273, 241, 115, 97, 159, 199, 41]],#chichenitza
    ['E',[265, 266, 471, 62, 0, 334, 302, 72, 159, 220, 149, 106]],#izamal
    ['F',[583, 68, 314, 273, 334, 0, 32, 388, 279, 63, 468, 228]],#playa del carmen
    ['G',[551, 36, 346, 241, 302, 32, 0, 256, 297, 95, 435, 195]],# puerto morales
    ['H',[196, 320, 525, 115, 72, 388, 256, 0, 212, 274, 80, 160]],#merida
    ['I',[409, 212, 417, 97, 159, 279, 297, 212, 0, 166, 291, 52]],#tizimni
    ['J',[470, 131, 251, 159, 220, 63, 95, 274, 166, 0, 366, 291]],#TUlum
    ['K',[171, 399, 605, 199, 149, 468, 435, 80, 291, 366, 0, 239]],#uxmal
    ['L',[355, 160, 365, 41, 106, 228, 195, 160, 52, 291, 239, 0]]#Valladolid
     ]

# %% [markdown]
# ## Definición de funciones

# %%
def CalculoFitness(individuo):
    #Sabemos cual es la distancia correcta al obtener los indices de la matriz dis usando el orden de las letras del codigo ascii
    suma=0
    #Calculamos la distancia entre ciudades
    for i in range(len(individuo)-1):
        actual=string.ascii_uppercase.index(individuo[i])
        sig=string.ascii_uppercase.index(individuo[i+1])
        suma+=dis[actual][1][sig]
    #calculamos la distancia a la ciudad de origen
    actual=string.ascii_uppercase.index(individuo[numCiudades-1])
    sig=string.ascii_uppercase.index(individuo[0])
        
    return suma+dis[actual][1][sig]
    
def CalculoProbSelec (num, fitness):
    x= 1 - ((fitness[num] - min(fitness))/max(fitness) )
    return x

def Mutacion(padre,r):
    for j in range(len(padre)):
        
        if random.random()>r:#Si es mayor mutamos
            if j+1==len(padre):#si es la ultima ciudad lo cambiamos con el primero
                aux=padre[0]
                padre[0]=padre[j]
                padre[j]=aux
            else:#Cambiamos un gen por el siguiente
                aux=padre[j+1]
                padre[j+1]=padre[j]
                padre[j]=aux                        
       
    return padre

def lectura (mejor):# funcion para decodificar las rutas
    ruta=[]
    for i in range (numCiudades):
        a=string.ascii_uppercase.index(mejor[i])
        ruta.append(ciudades[a])

    return ruta

# %% [markdown]
# ## Algoritmo genético

# %%
#variables para guardar registros
historico=[]

for r in Q:
    registro=[]#aqui guardaremos los datos para la variable que estemos probando
    poblacion=[]#poblacion con la que trabajaremos
    fitnes=[]#array con el fitness de los individuos
    Mejor_historico=[]#Mejor de la ejecucion
    letras=[]#
    epocas=0
    resumen=generaciones/50
    muestra=generaciones/10
    
    #genes posibles
    for i in range(numCiudades):
        letras.append(asci[i])

    #CABECERA
    print("NTOWN: ", numCiudades, "Poblacion total: ", numPoblacion, "NGEN: ", generaciones, "Q: ", r)

    #Generamos la poblacion inicial aleatoria
    for i in range(numPoblacion):
        ruta=[]
        opciones=[]
        for i in range(numCiudades):#dependiendo del número de ciudades habrá más o menos letras disponibles
            opciones.append(asci[i])
        for j in range(numCiudades):
            elegida=random.choice(opciones)#Ciudad elegida
            ruta.append(elegida)
            n=opciones.index(elegida)
            #la quitamos de la lista para no volver a la misma ciudad en la misma ruta
            if j!=numCiudades:
                opciones.pop(n)
        poblacion.append(ruta)


    pob=Enumerable(poblacion)#TRANSFORMAMOS POBLACION EN ENUMERABLE PARA PODER USAR LINQ
    fitnes=pob.select(lambda x: CalculoFitness(x))#calculamos el fitnes de los individuos
    fitnes=np.array(fitnes)
    while True:

        #Seleccion del padre
        aleatorio=random.randint(0,numPoblacion-1)
        Padre=empieza=aleatorio
        Flag=False #False = aleatorio --> final, True = 0 --> aleatorio
        numero=0

        while Flag==False or Padre<=(empieza-1): #Calculamos la probabilidad de todos los individuos de ser padres y vemos si se replica y si muta


            numero=random.random()

            prb=CalculoProbSelec(Padre, fitnes)

            #si es menor, se replica
            if numero<prb:
                #Sustituimos uno aleatorio
                aleatorio=random.randint(0,numPoblacion-1)
                #Mutamos al cromosoma del padre
                poblacion[aleatorio]=Mutacion(poblacion[Padre],r)
                #calculamos su fitnes
                fitnes[aleatorio]=CalculoFitness(poblacion[aleatorio])

            if Padre==numPoblacion-1:#Seguimos ejecutando sobre la poblacion de forma secuendial
                Padre=0
                Flag=True
            Padre+=1


        #comprobamos si alguno de los que hemos obtenido es mejor solución
        pob=Enumerable(poblacion)#TRANSFORMAMOS POBLACION EN ENUMERABLE PARA PODER USAR LINQ
        menorFitnes=pob.min(lambda x: CalculoFitness(x))
        mejor=pob.where(lambda x: CalculoFitness(x)==menorFitnes).take(1)#obtenemos el mejor individuo de la generacion

        if epocas==0:
            Mejor_historico=mejor[0]
            
        #guardamos el mejor fitnes encontrado
        if CalculoFitness(mejor[0]) < CalculoFitness(Mejor_historico):
            print("F. Histo:", CalculoFitness(Mejor_historico), "F. mejor: ",CalculoFitness(mejor[0]))
            Mejor_historico=mejor[0][:]

        
        
        #Mostramos el resumen de la ejecucion
        if epocas%resumen == 0 or epocas%muestra==0:

            aparece=pob.count(lambda x: CalculoFitness(x)==menorFitnes)#comparamos entre todos los individuos para saber cuales son igual que el mejor

            mayorFitnes=pob.max(lambda x: CalculoFitness(x))
            mediaFitness=pob.avg(lambda x: CalculoFitness(x))
    
            #individuo de consenso
            consenso=[]
            #Comparamos gen a gen cual es el que más se repite
            for i in range(numCiudades):
                posicion=[]
                for j in range(numPoblacion):
                    posicion.append(poblacion[j][i])
                consenso.append((mode(posicion)))

            #Mostramos el resumen
            print("\n\nGeneracion nº: ", epocas)
            print("Distancias: \nMedia: ", mediaFitness, "Minima: ", menorFitnes, "Mayor: ", mayorFitnes)       
            print("Mejor individuo de la población: ", lectura(mejor[0]), " %BEST (",(aparece/numPoblacion)*100, "%)")
            print('Individuo de consenso: ', consenso)
            print("\nMejor individuo hasta el momento: ", Mejor_historico)
            print("Con distancia:", CalculoFitness(Mejor_historico))

            #Guardamos los datos para las gráficas
            registro.append([epocas,[menorFitnes,mayorFitnes,mediaFitness], consenso])

            if epocas%muestra==0:
                print("Muestreo de la poblacion: ")
                print(pob.take(round(numPoblacion*0.2)))





        #fin de la ejecucion
        if epocas == generaciones:
            print("La mejor ruta que ha encontrado el algoritmo es: ", lectura(Mejor_historico))
            print("Con una distancia de total de: ", CalculoFitness(Mejor_historico))
            break
        epocas+=1
    
    #guardamos los datos de la ejecucion
    historico.append(registro[:])
# Out:
# duo de consenso:  ['A', 'D', 'K', 'H', 'G', 'J', 'L', 'E', 'F', 'C', 'I', 'B']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  8000
# Distancias:
# Media:  3377.0 Minima:  3377 Mayor:  3377
# Mejor individuo de la población:  ['Valladolid', 'merida', 'chichenitza', 'TUlum', 'playa del carmen', 'tizimni', 'puerto morales', 'uxmal', 'izamal', 'chetumal', 'Cancun', 'Campeche']  %BEST ( 100.0 %)
# Individuo de consenso:  ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
# Muestreo de la poblacion:
# [['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A'], ['L', 'H', 'D', 'J', 'F', 'I', 'G', 'K', 'E', 'C', 'B', 'A']]
#
#
# Generacion nº:  8400
# Distancias:
# Media:  3245.0 Minima:  3245 Mayor:  3245
# Mejor individuo de la población:  ['tizimni', 'chetumal', 'playa del carmen', 'Cancun', 'Campeche', 'Valladolid', 'chichenitza', 'izamal', 'TUlum', 'merida', 'puerto morales', 'uxmal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['I', 'C', 'F', 'B', 'A', 'L', 'D', 'E', 'J', 'H', 'G', 'K']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  8800
# Distancias:
# Media:  3299.0 Minima:  3299 Mayor:  3299
# Mejor individuo de la población:  ['uxmal', 'Valladolid', 'tizimni', 'merida', 'Campeche', 'playa del carmen', 'chetumal', 'chichenitza', 'TUlum', 'Cancun', 'izamal', 'puerto morales']  %BEST ( 100.0 %)
# Individuo de consenso:  ['K', 'L', 'I', 'H', 'A', 'F', 'C', 'D', 'J', 'B', 'E', 'G']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  9200
# Distancias:
# Media:  3109.0 Minima:  3109 Mayor:  3109
# Mejor individuo de la población:  ['chichenitza', 'Campeche', 'Valladolid', 'tizimni', 'izamal', 'puerto morales', 'TUlum', 'chetumal', 'merida', 'Cancun', 'playa del carmen', 'uxmal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['D', 'A', 'L', 'I', 'E', 'G', 'J', 'C', 'H', 'B', 'F', 'K']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  9600
# Distancias:
# Media:  3671.0 Minima:  3671 Mayor:  3671
# Mejor individuo de la población:  ['Cancun', 'tizimni', 'Valladolid', 'TUlum', 'merida', 'uxmal', 'playa del carmen', 'chichenitza', 'Campeche', 'puerto morales', 'izamal', 'chetumal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['B', 'I', 'L', 'J', 'H', 'K', 'F', 'D', 'A', 'G', 'E', 'C']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  10000
# Distancias:
# Media:  3617.0 Minima:  3617 Mayor:  3617
# Mejor individuo de la población:  ['Cancun', 'tizimni', 'izamal', 'uxmal', 'puerto morales', 'Campeche', 'playa del carmen', 'chichenitza', 'TUlum', 'chetumal', 'Valladolid', 'merida']  %BEST ( 100.0 %)
# Individuo de consenso:  ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
# Muestreo de la poblacion:
# [['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H'], ['B', 'I', 'E', 'K', 'G', 'A', 'F', 'D', 'J', 'C', 'L', 'H']]
#
#
# Generacion nº:  10400
# Distancias:
# Media:  3475.0 Minima:  3475 Mayor:  3475
# Mejor individuo de la población:  ['izamal', 'puerto morales', 'chichenitza', 'Cancun', 'chetumal', 'tizimni', 'merida', 'playa del carmen', 'Valladolid', 'uxmal', 'Campeche', 'TUlum']  %BEST ( 100.0 %)
# Individuo de consenso:  ['E', 'G', 'D', 'B', 'C', 'I', 'H', 'F', 'L', 'K', 'A', 'J']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  10800
# Distancias:
# Media:  2497.0 Minima:  2497 Mayor:  2497
# Mejor individuo de la población:  ['puerto morales', 'playa del carmen', 'Campeche', 'uxmal', 'merida', 'izamal', 'Valladolid', 'Cancun', 'tizimni', 'TUlum', 'chichenitza', 'chetumal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['G', 'F', 'A', 'K', 'H', 'E', 'L', 'B', 'I', 'J', 'D', 'C']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  11200
# Distancias:
# Media:  3291.0 Minima:  3291 Mayor:  3291
# Mejor individuo de la población:  ['uxmal', 'chetumal', 'Campeche', 'chichenitza', 'playa del carmen', 'Valladolid', 'Cancun', 'izamal', 'TUlum', 'tizimni', 'puerto morales', 'merida']  %BEST ( 100.0 %)
# Individuo de consenso:  ['K', 'C', 'A', 'D', 'F', 'L', 'B', 'E', 'J', 'I', 'G', 'H']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
#
#
# Generacion nº:  11600
# Distancias:
# Media:  3463.0 Minima:  3463 Mayor:  3463
# Mejor individuo de la población:  ['uxmal', 'puerto morales', 'izamal', 'playa del carmen', 'chetumal', 'Campeche', 'TUlum', 'merida', 'Valladolid', 'chichenitza', 'Cancun', 'tizimni']  %BEST ( 100.0 %)
# Individuo de consenso:  ['K', 'G', 'E', 'F', 'C', 'A', 'J', 'H', 'L', 'D', 'B', 'I']
#
# Mejor individuo hasta el momento:  ['L', 'D', 'E', 'H', 'A', 'K', 'I', 'J', 'F', 'G', 'B', 'C']
# Con distancia: 1877
# F. Histo: 1877 F. mejor:  1637
#
#
# Generacion nº:  12000
# Distancias:
# Media:  3340.0 Minima:  3340 Mayor:  3340
# Mejor individuo de la población:  ['Campeche', 'merida', 'chetumal', 'puerto morales', 'tizimni', 'uxmal', 'TUlum', 'Cancun', 'Valladolid', 'izamal', 'playa del carmen', 'chichenitza']  %BEST ( 100.0 %)
# Individuo de consenso:  ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
# Muestreo de la poblacion:
# [['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D'], ['A', 'H', 'C', 'G', 'I', 'K', 'J', 'B', 'L', 'E', 'F', 'D']]
#
#
# Generacion nº:  12400
# Distancias:
# Media:  3783.0 Minima:  3783 Mayor:  3783
# Mejor individuo de la población:  ['TUlum', 'uxmal', 'Valladolid', 'chetumal', 'izamal', 'playa del carmen', 'chichenitza', 'Cancun', 'merida', 'Campeche', 'puerto morales', 'tizimni']  %BEST ( 100.0 %)
# Individuo de consenso:  ['J', 'K', 'L', 'C', 'E', 'F', 'D', 'B', 'H', 'A', 'G', 'I']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  12800
# Distancias:
# Media:  3224.0 Minima:  3224 Mayor:  3224
# Mejor individuo de la población:  ['tizimni', 'chetumal', 'Valladolid', 'merida', 'Cancun', 'playa del carmen', 'chichenitza', 'Campeche', 'puerto morales', 'TUlum', 'izamal', 'uxmal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['I', 'C', 'L', 'H', 'B', 'F', 'D', 'A', 'G', 'J', 'E', 'K']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  13200
# Distancias:
# Media:  2882.0 Minima:  2882 Mayor:  2882
# Mejor individuo de la población:  ['Valladolid', 'chichenitza', 'tizimni', 'Campeche', 'chetumal', 'puerto morales', 'izamal', 'uxmal', 'TUlum', 'Cancun', 'playa del carmen', 'merida']  %BEST ( 100.0 %)
# Individuo de consenso:  ['L', 'D', 'I', 'A', 'C', 'G', 'E', 'K', 'J', 'B', 'F', 'H']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  13600
# Distancias:
# Media:  3519.0 Minima:  3519 Mayor:  3519
# Mejor individuo de la población:  ['puerto morales', 'chichenitza', 'playa del carmen', 'izamal', 'Valladolid', 'merida', 'Campeche', 'Cancun', 'uxmal', 'TUlum', 'tizimni', 'chetumal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['G', 'D', 'F', 'E', 'L', 'H', 'A', 'B', 'K', 'J', 'I', 'C']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  14000
# Distancias:
# Media:  3125.0 Minima:  3125 Mayor:  3125
# Mejor individuo de la población:  ['Cancun', 'merida', 'Valladolid', 'tizimni', 'Campeche', 'chichenitza', 'puerto morales', 'TUlum', 'playa del carmen', 'izamal', 'uxmal', 'chetumal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
# Muestreo de la poblacion:
# [['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C'], ['B', 'H', 'L', 'I', 'A', 'D', 'G', 'J', 'F', 'E', 'K', 'C']]
#
#
# Generacion nº:  14400
# Distancias:
# Media:  3626.0 Minima:  3626 Mayor:  3626
# Mejor individuo de la población:  ['uxmal', 'TUlum', 'Campeche', 'playa del carmen', 'chetumal', 'Valladolid', 'chichenitza', 'Cancun', 'izamal', 'merida', 'tizimni', 'puerto morales']  %BEST ( 100.0 %)
# Individuo de consenso:  ['K', 'J', 'A', 'F', 'C', 'L', 'D', 'B', 'E', 'H', 'I', 'G']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  14800
# Distancias:
# Media:  3330.0 Minima:  3330 Mayor:  3330
# Mejor individuo de la población:  ['Cancun', 'uxmal', 'playa del carmen', 'puerto morales', 'TUlum', 'Valladolid', 'tizimni', 'merida', 'chetumal', 'izamal', 'Campeche', 'chichenitza']  %BEST ( 100.0 %)
# Individuo de consenso:  ['B', 'K', 'F', 'G', 'J', 'L', 'I', 'H', 'C', 'E', 'A', 'D']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  15200
# Distancias:
# Media:  3276.0 Minima:  3276 Mayor:  3276
# Mejor individuo de la población:  ['Cancun', 'TUlum', 'chetumal', 'puerto morales', 'Valladolid', 'merida', 'chichenitza', 'izamal', 'tizimni', 'uxmal', 'playa del carmen', 'Campeche']  %BEST ( 100.0 %)
# Individuo de consenso:  ['B', 'J', 'C', 'G', 'L', 'H', 'D', 'E', 'I', 'K', 'F', 'A']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  15600
# Distancias:
# Media:  3054.0 Minima:  3054 Mayor:  3054
# Mejor individuo de la población:  ['tizimni', 'TUlum', 'Valladolid', 'izamal', 'Campeche', 'merida', 'puerto morales', 'uxmal', 'chichenitza', 'playa del carmen', 'Cancun', 'chetumal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['I', 'J', 'L', 'E', 'A', 'H', 'G', 'K', 'D', 'F', 'B', 'C']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  16000
# Distancias:
# Media:  3751.0 Minima:  3751 Mayor:  3751
# Mejor individuo de la población:  ['TUlum', 'Valladolid', 'izamal', 'puerto morales', 'tizimni', 'chichenitza', 'merida', 'playa del carmen', 'Campeche', 'chetumal', 'Cancun', 'uxmal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
# Muestreo de la poblacion:
# [['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K'], ['J', 'L', 'E', 'G', 'I', 'D', 'H', 'F', 'A', 'C', 'B', 'K']]
#
#
# Generacion nº:  16400
# Distancias:
# Media:  2607.0 Minima:  2607 Mayor:  2607
# Mejor individuo de la población:  ['merida', 'tizimni', 'Valladolid', 'puerto morales', 'TUlum', 'chetumal', 'Campeche', 'Cancun', 'playa del carmen', 'uxmal', 'izamal', 'chichenitza']  %BEST ( 100.0 %)
# Individuo de consenso:  ['H', 'I', 'L', 'G', 'J', 'C', 'A', 'B', 'F', 'K', 'E', 'D']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  16800
# Distancias:
# Media:  3338.0 Minima:  3338 Mayor:  3338
# Mejor individuo de la población:  ['Cancun', 'tizimni', 'chetumal', 'Valladolid', 'TUlum', 'playa del carmen', 'Campeche', 'chichenitza', 'puerto morales', 'izamal', 'uxmal', 'merida']  %BEST ( 100.0 %)
# Individuo de consenso:  ['B', 'I', 'C', 'L', 'J', 'F', 'A', 'D', 'G', 'E', 'K', 'H']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  17200
# Distancias:
# Media:  2394.0 Minima:  2394 Mayor:  2394
# Mejor individuo de la población:  ['merida', 'Valladolid', 'tizimni', 'chichenitza', 'izamal', 'uxmal', 'Cancun', 'playa del carmen', 'chetumal', 'TUlum', 'puerto morales', 'Campeche']  %BEST ( 100.0 %)
# Individuo de consenso:  ['H', 'L', 'I', 'D', 'E', 'K', 'B', 'F', 'C', 'J', 'G', 'A']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  17600
# Distancias:
# Media:  3403.0 Minima:  3403 Mayor:  3403
# Mejor individuo de la población:  ['chichenitza', 'Campeche', 'puerto morales', 'chetumal', 'Cancun', 'Valladolid', 'merida', 'TUlum', 'tizimni', 'izamal', 'uxmal', 'playa del carmen']  %BEST ( 100.0 %)
# Individuo de consenso:  ['D', 'A', 'G', 'C', 'B', 'L', 'H', 'J', 'I', 'E', 'K', 'F']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  18000
# Distancias:
# Media:  2366.0 Minima:  2366 Mayor:  2366
# Mejor individuo de la población:  ['TUlum', 'chichenitza', 'izamal', 'Valladolid', 'tizimni', 'playa del carmen', 'Cancun', 'puerto morales', 'chetumal', 'merida', 'Campeche', 'uxmal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
# Muestreo de la poblacion:
# [['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K'], ['J', 'D', 'E', 'L', 'I', 'F', 'B', 'G', 'C', 'H', 'A', 'K']]
#
#
# Generacion nº:  18400
# Distancias:
# Media:  3461.0 Minima:  3461 Mayor:  3461
# Mejor individuo de la población:  ['playa del carmen', 'chetumal', 'puerto morales', 'Campeche', 'chichenitza', 'tizimni', 'uxmal', 'Cancun', 'Valladolid', 'merida', 'TUlum', 'izamal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['F', 'C', 'G', 'A', 'D', 'I', 'K', 'B', 'L', 'H', 'J', 'E']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  18800
# Distancias:
# Media:  3084.0 Minima:  3084 Mayor:  3084
# Mejor individuo de la población:  ['izamal', 'chetumal', 'Cancun', 'playa del carmen', 'puerto morales', 'uxmal', 'Valladolid', 'TUlum', 'Campeche', 'chichenitza', 'tizimni', 'merida']  %BEST ( 100.0 %)
# Individuo de consenso:  ['E', 'C', 'B', 'F', 'G', 'K', 'L', 'J', 'A', 'D', 'I', 'H']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  19200
# Distancias:
# Media:  3239.0 Minima:  3239 Mayor:  3239
# Mejor individuo de la población:  ['TUlum', 'uxmal', 'chichenitza', 'izamal', 'tizimni', 'puerto morales', 'Campeche', 'merida', 'playa del carmen', 'Valladolid', 'Cancun', 'chetumal']  %BEST ( 100.0 %)
# Individuo de consenso:  ['J', 'K', 'D', 'E', 'I', 'G', 'A', 'H', 'F', 'L', 'B', 'C']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  19600
# Distancias:
# Media:  2597.0 Minima:  2597 Mayor:  2597
# Mejor individuo de la población:  ['Campeche', 'Valladolid', 'chichenitza', 'chetumal', 'uxmal', 'tizimni', 'TUlum', 'puerto morales', 'playa del carmen', 'Cancun', 'izamal', 'merida']  %BEST ( 100.0 %)
# Individuo de consenso:  ['A', 'L', 'D', 'C', 'K', 'I', 'J', 'G', 'F', 'B', 'E', 'H']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
#
#
# Generacion nº:  20000
# Distancias:
# Media:  2749.0 Minima:  2749 Mayor:  2749
# Mejor individuo de la población:  ['tizimni', 'uxmal', 'merida', 'izamal', 'chichenitza', 'puerto morales', 'Cancun', 'TUlum', 'chetumal', 'Valladolid', 'playa del carmen', 'Campeche']  %BEST ( 100.0 %)
# Individuo de consenso:  ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A']
#
# Mejor individuo hasta el momento:  ['A', 'C', 'J', 'G', 'B', 'F', 'L', 'I', 'D', 'E', 'H', 'K']
# Con distancia: 1637
# Muestreo de la poblacion:
# [['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A'], ['I', 'K', 'H', 'E', 'D', 'G', 'B', 'J', 'C', 'L', 'F', 'A']]
# La mejor ruta que ha encontrado el algoritmo es:  ['Campeche', 'chetumal', 'TUlum', 'puerto morales', 'Cancun', 'playa del carmen', 'Valladolid', 'tizimni', 'chichenitza', 'izamal', 'merida', 'uxmal']
# Con una distancia de total de:  1637

# %% [markdown]
# ## Gráficas con los resultados

# %%
h=np.array(historico)
x=[]
y=[]
y1=[]
y2=[]
y3=[]
individuo=[]
#Descomprimimos en arrays los valores registrados
for i in range(len(h[0])):
    y1.append(h[2][i][1][0])
    y2.append(h[2][i][1][1])
    y3.append(h[2][i][1][2])
    x.append(h[2][i][0])
    individuo.append(h[2][i][2])
y.append(y1)
y.append(y2)
y.append(y3)
# Out:
# <ipython-input-21-e36f1dc96e01>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   h=np.array(historico)

# %%
import pylab as pl
fig,ax=pl.subplots(1,3, figsize=(20,5))
index=0
labels=['Distancia Minima','Distancia Maxima', 'Distancia Media']
fig.suptitle("Q = 0.95 ")
#for row in ax:
for col in ax:
    col.plot(x,y[index])
    col.set_xlabel('Generaciones')
    col.set_ylabel(labels[index])
    index+=1
pl.show()
#pl.plot(x,y[0][0])

# %% [markdown]
# #### Individuo de consenso

# %%
#Vemos el número de veces que se repite cada individuo de consenso
for i in range(len(individuo)):
    individuo[i]= ''.join(individuo[i])

conteo = {i:individuo.count(i) for i in individuo}
print(conteo)
# Out:
# {'JIFBKFDEAEJF': 1, 'EAKGILJFDBHC': 1, 'JHDLICFAGKEB': 1, 'BHKFIDGLECAJ': 1, 'LCKADJEGFIHB': 1, 'EHABFCIGLDJK': 1, 'LAHJFGDKCIEB': 1, 'BFLACJIDGEKH': 1, 'IHJKACLDFBEG': 1, 'DJEBFAIGKHLC': 1, 'BDJKHAICGFEL': 1, 'BKDJFAHIGELC': 1, 'KHGELJACDIBF': 1, 'GFIELDAJKHCB': 1, 'CABLFDHGJKEI': 1, 'HKJBAGECFILD': 1, 'CJAILGDBFHEK': 1, 'DGKAHJIFBLEC': 1, 'EBLJFDHKGACI': 1, 'ADKHGJLEFCIB': 1, 'LHDJFIGKECBA': 1, 'ICFBALDEJHGK': 1, 'KLIHAFCDJBEG': 1, 'DALIEGJCHBFK': 1, 'BILJHKFDAGEC': 1, 'BIEKGAFDJCLH': 1, 'EGDBCIHFLKAJ': 1, 'GFAKHELBIJDC': 1, 'KCADFLBEJIGH': 1, 'KGEFCAJHLDBI': 1, 'AHCGIKJBLEFD': 1, 'JKLCEFDBHAGI': 1, 'ICLHBFDAGJEK': 1, 'LDIACGEKJBFH': 1, 'GDFELHABKJIC': 1, 'BHLIADGJFEKC': 1, 'KJAFCLDBEHIG': 1, 'BKFGJLIHCEAD': 1, 'BJCGLHDEIKFA': 1, 'IJLEAHGKDFBC': 1, 'JLEGIDHFACBK': 1, 'HILGJCABFKED': 1, 'BICLJFADGEKH': 1, 'HLIDEKBFCJGA': 1, 'DAGCBLHJIEKF': 1, 'JDELIFBGCHAK': 1, 'FCGADIKBLHJE': 1, 'ECBFGKLJADIH': 1, 'JKDEIGAHFLBC': 1, 'ALDCKIJGFBEH': 1, 'IKHEDGBJCLFA': 1}
