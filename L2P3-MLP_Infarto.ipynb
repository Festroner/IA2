# %% [markdown]
# ## Práctica 3
#
# ### Predicción de sufrir un infarto con Keras

# %%
# Importamos las librerias

import pandas as pd
import numpy as np
import keras_metrics

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from tensorflow.keras import utils as k
from tensorflow.keras.callbacks import EarlyStopping

file= 'infarto.csv'
dt=pd.read_csv(file, sep=";")


# Aunque no seamos expertos en el tema entendemos que las columnas casado y trabajo no aportan nada para el modelo
# La residencia si porque la calidad del aire es diferente

# Vemos si hay valores nulos

dt=dt.drop(['id','casado', 'trabajo'], axis=1)

print("Numero de filas con NaN values:\n",dt.isnull().sum())
print("\n\nComo no hay muchos NaN las filas que cuenten con valores nulos las descartamos")

# Quitamos las filas con valores nulos

dt=dt.dropna()
dt.head(5)
# Out:
# Numero de filas con NaN values:
#  genero                    0
# edad                      0
# hipertensión              0
# enfermedad_coronaria      0
# residencia                0
# nivel_glucosa             0
# bmi                     201
# uso_tabaco                0
# infarto                   0
# dtype: int64
#
#
# Como no hay muchos NaN las filas que cuenten con valores nulos las descartamos
#       genero  edad  hipertensión  enfermedad_coronaria residencia  \
# 0  Masculino  67.0             0                     1     Urbana
# 2  Masculino  80.0             0                     1      Rural
# 3   Femenino  49.0             0                     0     Urbana
# 4   Femenino  79.0             1                     0      Rural
# 5  Masculino  81.0             0                     0     Urbana
#
#    nivel_glucosa   bmi  uso_tabaco  infarto
# 0         228.69  36.6  Ex fumador        1
# 2         105.92  32.5       Nunca        1
# 3         171.23  34.4     Fumador        1
# 4         174.12  24.0       Nunca        1
# 5         186.21  29.0  Ex fumador        1

# %% [markdown]
# #### Categorizacion de columnas

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#Transformamos las columnas necesarias con to_categorical
#antes 

columna1=np.array(dt["genero"])
columna2=np.array(dt["residencia"])
columna3=np.array(dt["uso_tabaco"])
label_encoder = LabelEncoder()

genero = label_encoder.fit_transform(columna1)
residencia= label_encoder.fit_transform(columna2)
tabaco= label_encoder.fit_transform(columna3)


dt["genero"]= k.to_categorical(genero)
dt["residencia"]= k.to_categorical(residencia)
dt["uso_tabaco"]= k.to_categorical(tabaco)

# %% [markdown]
# #### Normalización de los datos y obtención del conjunto de prueba

# %%
#NORMALIZAMOS LOS DATOS POR COLUMNAS

def minmax_norm(datos_input): 
    return (datos_input - dt.min()) / ( dt.max() - dt.min())
dt=minmax_norm(dt)
dt.head(5)

#OBTENEMOS EL CONJUNTO DE PRUEBA

esperada= dt.iloc[:, 8]
esperada

datos= dt.iloc[:,0:8]
datos
# Out:
#       genero      edad  hipertensión  enfermedad_coronaria  residencia  \
# 0        0.0  0.816895           0.0                   1.0         0.0
# 2        0.0  0.975586           0.0                   1.0         1.0
# 3        1.0  0.597168           0.0                   0.0         0.0
# 4        1.0  0.963379           1.0                   0.0         1.0
# 5        0.0  0.987793           0.0                   0.0         0.0
# ...      ...       ...           ...                   ...         ...
# 5104     1.0  0.157715           0.0                   0.0         1.0
# 5106     1.0  0.987793           0.0                   0.0         0.0
# 5107     1.0  0.426270           0.0                   0.0         1.0
# 5108     0.0  0.621582           0.0                   0.0         1.0
# 5109     1.0  0.536133           0.0                   0.0         0.0
#
#       nivel_glucosa       bmi  uso_tabaco
# 0          0.801265  0.301260         1.0
# 2          0.234512  0.254296         0.0
# 3          0.536008  0.276060         0.0
# 4          0.549349  0.156930         0.0
# 5          0.605161  0.214204         1.0
# ...             ...       ...         ...
# 5104       0.221402  0.095074         0.0
# 5106       0.323516  0.340206         0.0
# 5107       0.128658  0.232532         0.0
# 5108       0.513203  0.175258         1.0
# 5109       0.139230  0.182131         0.0
#
# [4909 rows x 8 columns]

# %%
#ENTRENAMIENTO, VALIDACION

#NO INFARTOS
x_train, x_resto, y_train, y_resto= train_test_split(datos[209::3], esperada[209::3], test_size=0.3)
x_test, x_pred, y_test, y_pred = train_test_split(x_resto, y_resto, test_size=0.2)

#INFARTOS
x_in_train, x_in_resto,y_in_train,y_in_resto = train_test_split(datos[:209], esperada[:209], test_size=0.2)
x_in_test, x_in_pred,y_in_test,y_in_pred = train_test_split(x_in_resto, y_in_resto, test_size=0.2)


#Sumamos los casos para que la red cuente con ambos casos en cada etapa
x_train=pd.concat([x_in_train, x_train], axis=0)
x_test=pd.concat([x_in_test, x_test], axis=0)
x_pred=pd.concat([x_in_pred, x_pred], axis=0)

y_train=pd.concat([y_in_train, y_train], axis=0)
y_test=pd.concat([y_in_test, y_test], axis=0)
y_pred=pd.concat([y_in_pred, y_pred], axis=0)

print(len(x_train))
print(len(x_in_train))
# Out:
# 1263
# 167

# %% [markdown]
# #### Creamos la arquitectura de la red neuronal

# %%
#PROCEDEMOS A CREAR LA RED
# Configuración del modelo
# Lo primero es crear un modelo Secuencial vacio
# Ahora, añadimos 3 capas.
# La capa de entrada
# La capa oculta
# La última capa es la de salida con una neurona

model=Sequential()

#APLICANDO LA FORMULA SABEMOS QUE EN LA CAPA OCULTA DEBEMOS TENER ENTRE 245 Y 981 NEURONAS
model.add(Dense(500, 'sigmoid', 8))
model.add(Dense(400, 'relu'))
model.add(Dense(1, 'sigmoid'))# UNA SALIDA (0/1)

# Entrenamiento de la red 
# Con model.fit indicamos las entradas y salidas y la cantidad de iteraciones de aprendizaje (epochs)

model.compile(loss="mean_squared_error", optimizer='adam',metrics="accuracy")
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
model.fit(x=x_train,y=y_train,validation_split=0.2, epochs=1000, shuffle=True, use_multiprocessing=True)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1650 - accuracy: 0.7600 - val_loss: 6.6973e-05 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1392 - accuracy: 0.8513 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.8245 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1375 - accuracy: 0.8309 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.8453 - val_loss: 0.0558 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.8294 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.8409 - val_loss: 0.0309 - val_accuracy: 0.9960
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1195 - accuracy: 0.8441 - val_loss: 0.0308 - val_accuracy: 0.9960
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.8502 - val_loss: 0.0235 - val_accuracy: 0.9960
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1100 - accuracy: 0.8503 - val_loss: 0.0190 - val_accuracy: 0.9960
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.8480 - val_loss: 0.0244 - val_accuracy: 0.9921
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.8273 - val_loss: 0.0243 - val_accuracy: 0.9921
# Epoch 13/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.8398 - val_loss: 0.0312 - val_accuracy: 0.9881
# Epoch 14/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.8504 - val_loss: 0.0316 - val_accuracy: 0.9802
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.8563 - val_loss: 0.0420 - val_accuracy: 0.9605
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.8452 - val_loss: 0.0253 - val_accuracy: 0.9921
# Epoch 17/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.8660 - val_loss: 0.0487 - val_accuracy: 0.9447
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.8493 - val_loss: 0.0751 - val_accuracy: 0.9249
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.8499 - val_loss: 0.0262 - val_accuracy: 0.9802
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.8442 - val_loss: 0.0204 - val_accuracy: 0.9960
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.8483 - val_loss: 0.0182 - val_accuracy: 0.9960
# Epoch 22/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.8528 - val_loss: 0.0683 - val_accuracy: 0.9249
# Epoch 23/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.8434 - val_loss: 0.0112 - val_accuracy: 0.9960
# Epoch 24/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.8619 - val_loss: 0.0354 - val_accuracy: 0.9644
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.8497 - val_loss: 0.0284 - val_accuracy: 0.9763
# Epoch 26/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.8481 - val_loss: 0.0622 - val_accuracy: 0.9289
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.8490 - val_loss: 0.0362 - val_accuracy: 0.9684
# Epoch 28/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.8545 - val_loss: 0.0183 - val_accuracy: 0.9960
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.8528 - val_loss: 0.0253 - val_accuracy: 0.9802
# Epoch 30/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.8508 - val_loss: 0.0399 - val_accuracy: 0.9526
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.8699 - val_loss: 0.0538 - val_accuracy: 0.9289
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.8613 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1122 - accuracy: 0.8467 - val_loss: 0.0473 - val_accuracy: 0.9486
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.8426 - val_loss: 0.0402 - val_accuracy: 0.9565
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.8633 - val_loss: 0.0088 - val_accuracy: 0.9960
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.8395 - val_loss: 0.0383 - val_accuracy: 0.9644
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.8391 - val_loss: 0.0306 - val_accuracy: 0.9723
# Epoch 38/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.8489 - val_loss: 0.0612 - val_accuracy: 0.9249
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.8523 - val_loss: 0.0109 - val_accuracy: 0.9960
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.8522 - val_loss: 0.0342 - val_accuracy: 0.9644
# Epoch 41/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.8630 - val_loss: 0.0411 - val_accuracy: 0.9486
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1018 - accuracy: 0.8559 - val_loss: 0.0093 - val_accuracy: 0.9960
# Epoch 43/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.8545 - val_loss: 0.0536 - val_accuracy: 0.9289
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.8593 - val_loss: 0.0229 - val_accuracy: 0.9802
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.8505 - val_loss: 0.0292 - val_accuracy: 0.9723
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.8398 - val_loss: 0.0528 - val_accuracy: 0.9289
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.8426 - val_loss: 0.0396 - val_accuracy: 0.9565
# Epoch 48/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.8628 - val_loss: 0.0544 - val_accuracy: 0.9328
# Epoch 49/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.8634 - val_loss: 0.0319 - val_accuracy: 0.9684
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.8499 - val_loss: 0.0257 - val_accuracy: 0.9763
# Epoch 51/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0902 - accuracy: 0.8744 - val_loss: 0.0282 - val_accuracy: 0.9763
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.8570 - val_loss: 0.0502 - val_accuracy: 0.9328
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.8561 - val_loss: 0.0164 - val_accuracy: 0.9921
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0951 - accuracy: 0.8604 - val_loss: 0.0129 - val_accuracy: 0.9960
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0960 - accuracy: 0.8621 - val_loss: 0.0541 - val_accuracy: 0.9289
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.8485 - val_loss: 0.0304 - val_accuracy: 0.9684
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.8536 - val_loss: 0.0269 - val_accuracy: 0.9763
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.8461 - val_loss: 0.0529 - val_accuracy: 0.9289
# Epoch 59/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.8449 - val_loss: 0.0193 - val_accuracy: 0.9842
# Epoch 60/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.8487 - val_loss: 0.0370 - val_accuracy: 0.9605
# Epoch 61/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.8261 - val_loss: 0.0174 - val_accuracy: 0.9960
# Epoch 62/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.8496 - val_loss: 0.0296 - val_accuracy: 0.9684
# Epoch 63/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.8630 - val_loss: 0.0082 - val_accuracy: 0.9960
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.8568 - val_loss: 0.0671 - val_accuracy: 0.8972
# Epoch 65/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.8284 - val_loss: 0.0188 - val_accuracy: 0.9881
# Epoch 66/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.8711 - val_loss: 0.0400 - val_accuracy: 0.9565
# Epoch 67/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.8657 - val_loss: 0.0482 - val_accuracy: 0.9328
# Epoch 68/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.8609 - val_loss: 0.0291 - val_accuracy: 0.9684
# Epoch 69/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0990 - accuracy: 0.8429 - val_loss: 0.0388 - val_accuracy: 0.9565
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1028 - accuracy: 0.8433 - val_loss: 0.0452 - val_accuracy: 0.9368
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.8648 - val_loss: 0.0308 - val_accuracy: 0.9644
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.8538 - val_loss: 0.0266 - val_accuracy: 0.9763
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.8445 - val_loss: 0.0347 - val_accuracy: 0.9644
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.8494 - val_loss: 0.0187 - val_accuracy: 0.9842
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1110 - accuracy: 0.8409 - val_loss: 0.0356 - val_accuracy: 0.9605
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.8310 - val_loss: 0.0332 - val_accuracy: 0.9644
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.8115 - val_loss: 0.0216 - val_accuracy: 0.9842
# Epoch 78/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0920 - accuracy: 0.8768 - val_loss: 0.0432 - val_accuracy: 0.9407
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.8696 - val_loss: 0.0167 - val_accuracy: 0.9921
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.8606 - val_loss: 0.0332 - val_accuracy: 0.9605
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.8469 - val_loss: 0.0336 - val_accuracy: 0.9644
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.8433 - val_loss: 0.0289 - val_accuracy: 0.9763
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.8445 - val_loss: 0.0387 - val_accuracy: 0.9565
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.8830 - val_loss: 0.0248 - val_accuracy: 0.9763
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.8418 - val_loss: 0.0233 - val_accuracy: 0.9842
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.8540 - val_loss: 0.0450 - val_accuracy: 0.9368
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.8301 - val_loss: 0.0086 - val_accuracy: 0.9960
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.8499 - val_loss: 0.0167 - val_accuracy: 0.9921
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.8740 - val_loss: 0.0319 - val_accuracy: 0.9644
# Epoch 90/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.8254 - val_loss: 0.0387 - val_accuracy: 0.9486
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.8549 - val_loss: 0.0537 - val_accuracy: 0.9170
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.8617 - val_loss: 0.0237 - val_accuracy: 0.9802
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.8580 - val_loss: 0.0282 - val_accuracy: 0.9644
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.8609 - val_loss: 0.0333 - val_accuracy: 0.9644
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.8422 - val_loss: 0.0324 - val_accuracy: 0.9644
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.8508 - val_loss: 0.0448 - val_accuracy: 0.9328
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.8461 - val_loss: 0.0524 - val_accuracy: 0.9209
# Epoch 98/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0968 - accuracy: 0.8559 - val_loss: 0.0314 - val_accuracy: 0.9644
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.8623 - val_loss: 0.0396 - val_accuracy: 0.9526
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.8549 - val_loss: 0.0298 - val_accuracy: 0.9644

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix

y_pred1 = model.predict(x_pred)
y_pred1 = y_pred1.round(0)

# Evaluamos el modelo 
scores = model.evaluate(x_test, y_test)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 13/13 [==============================] - 0s 768us/step - loss: 0.0735 - accuracy: 0.8998
#
# accuracy: 89.98%

# %%
# Mostramos los resultados de precision y recall

print(precision_score(y_pred, y_pred1 , average="macro"))
print(recall_score(y_pred, y_pred1 , average="macro"))
# Out:
# 0.5885416666666667
# 0.57953216374269

# %%
# Mostramos los resultados de la matriz de confusión

cm = confusion_matrix(y_pred, y_pred1)
print(cm)
# Out:
# [[89  6]
#  [ 7  2]]
